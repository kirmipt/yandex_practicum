# %% [markdown]
# Инсайты по проекту
# <br>
# # 1 Осмотр данных
# 1.1 Возможность совпадения пропусков двух столбцов
# # 2.1 Обработка пропусков/аномалий
# <br>2.1.1 Задаться вопросом - в чем причина аномалий?
# <br>2.1.2 Причины - опечатки (i.e. лишний 0), ошибка в единицах измерений
# <br>2.1.3 Замена пропусков на медиану
# <br>2.1.4 Замена пропусков на медианы групп по столбцу, признак которого связан с нашим, имеющим пропуски
# # 2.3 Типы данных
# <br>2.3.1 изменить на float на int, если целые
# # 2.4 Неявные дупликаты
# 2.4.1 str.lower   .value_counts
# <br>2.4.2 apply функцию из словаря+цикла - не додумался использовать apply, хотел цикл по строкам сделать
# 2.4.3 Когда все пропущенные исправлены - нужен (повторный) чек дупликатов
# # 2.6 Категоризация численного признака
# 2.6.1 Это было в карпове, но я забыл, также было в sql через case
# ____
# # 3 Исследование данных и проверка гипотез
# 3.1 Cтруктура гипотез в прошлом проекте была - groupby(столбец1, столбец2).count(зависимый столбец0)
# <br>3.2 Здесь проще - просто смотрим влияние каждого в отдельности (т.е. одного) столбца на зависимый
# <br>3.3 Зависимый столбец - бинарный, незав - номинативный/дискретный
# <br> pivot_table(ind=незав.столбец, col=завис.ст, values=любой.ст, aggfunc=count(незав.ст))
# # 4 Выводы
# 4.1 Меня смутили выводы без какой-либо проверки стат. значимости(здесь можно применить хи-квадрат)
# <br>"1-2% разница enough при размере груп 2-10к"
# <br>4.2 Не додумался до вывода - смотреть на закономерность только крупных групп, тк маленькие недостоверны
# # Новый синтаксис
# .style.format - оформление цифр (было в 1.8 Карпова, который я не практиковал)
